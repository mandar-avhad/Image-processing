# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

from google.colab.patches import cv2_imshow

# %%
im = cv2.imread('/content/bag1_view1.jpeg')
imgray = cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)

# %%
ret,thresh = cv2.threshold(imgray,75,255,0)
plt.imshow(thresh)
cv2.imwrite("new.jpg",thresh)
# Out:
# True

# %%
contours, hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

# %%
cv2.drawContours(im, contours, -1, (0, 255, 0), 3)
plt.imshow(im)

# %%
cnt = sorted(contours, key=cv2.contourArea, reverse=True)

# %%
cv2.drawContours(im, cnt, 1, (0, 255, 0), 3)
plt.imshow(im)

# %%
rect = cv2.boundingRect(cnt[1])
print(cv2.contourArea(cnt[1]))
x,y,w,h = cv2.boundingRect(cnt[1])
# Out:
# 32587.0

# %%
cv2.rectangle(im,(x,y),(x+w,y+h),(0,255,0),2)
cv2.putText(im,'depth: '+str(w),(x-10, y+h+10),0,0.3,(0,255,0))
cv2.putText(im,'height: '+str(h),(x+w+10, y-10),0,0.3,(0,255,0))
# Out:
# array([[[192, 196, 197],
#         [192, 196, 197],
#         [193, 197, 198],
#         ...,
#         [182, 182, 188],
#         [181, 181, 187],
#         [181, 181, 187]],
#
#        [[192, 196, 197],
#         [192, 196, 197],
#         [192, 196, 197],
#         ...,
#         [182, 182, 188],
#         [181, 181, 187],
#         [181, 181, 187]],
#
#        [[191, 195, 196],
#         [191, 195, 196],
#         [191, 195, 196],
#         ...,
#         [182, 182, 188],
#         [181, 181, 187],
#         [181, 181, 187]],
#
#        ...,
#
#        [[146, 155, 169],
#         [146, 155, 169],
#         [146, 155, 169],
#         ...,
#         [133, 149, 165],
#         [133, 149, 165],
#         [133, 149, 165]],
#
#        [[146, 155, 169],
#         [146, 155, 169],
#         [146, 155, 169],
#         ...,
#         [134, 150, 166],
#         [134, 150, 166],
#         [134, 150, 166]],
#
#        [[146, 155, 169],
#         [146, 155, 169],
#         [146, 155, 169],
# ...

# %%
cv2_imshow(im)
# Out:
# <PIL.Image.Image image mode=RGB size=544x1152 at 0x7F2C123058D0>

# %%
cv2.imwrite("res_b1_view1.jpeg",im)
# Out:
# True

# %%
print(x,y,w,h)
# Out:
# 229 353 151 260

# %%
im1 = cv2.imread('/content/bag1_view2.jpeg')
imgray1 = cv2.cvtColor(im1,cv2.COLOR_BGR2GRAY)

# %%
ret,thresh1 = cv2.threshold(imgray1,75,255,0)
plt.imshow(thresh1)
cv2.imwrite("new1.jpg",thresh1)
# Out:
# True

# %%
contours1, hierarchy = cv2.findContours(thresh1,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

# %%
cv2.drawContours(im1, contours1, -1, (0, 255, 0), 3)
plt.imshow(im1)

# %%
cnt1 = sorted(contours1, key=cv2.contourArea, reverse=True)

# %%
cv2.drawContours(im1, cnt1, 1, (0, 255, 0), 3)
plt.imshow(im1)

# %%
rect1 = cv2.boundingRect(cnt1[1])
print(cv2.contourArea(cnt1[1]))
x1,y1,w1,h1 = cv2.boundingRect(cnt1[1])
# Out:
# 41686.0

# %%
cv2.rectangle(im1,(x1,y1),(x1+w1,y1+h1),(0,255,0),2)
cv2.putText(im1,'breadth: '+str(w1),(x1-10, y1+h1+10),0,0.3,(0,255,0))
cv2.putText(im1,'height: '+str(h1),(x1+w1+10, y1-10),0,0.3,(0,255,0))
# Out:
# array([[[192, 196, 197],
#         [193, 197, 198],
#         [193, 197, 198],
#         ...,
#         [172, 174, 184],
#         [171, 173, 183],
#         [171, 173, 183]],
#
#        [[193, 197, 198],
#         [193, 197, 198],
#         [193, 197, 198],
#         ...,
#         [171, 173, 183],
#         [171, 173, 183],
#         [171, 173, 183]],
#
#        [[193, 197, 198],
#         [193, 197, 198],
#         [193, 197, 198],
#         ...,
#         [171, 173, 183],
#         [171, 173, 183],
#         [170, 172, 182]],
#
#        ...,
#
#        [[144, 154, 172],
#         [144, 154, 172],
#         [144, 154, 172],
#         ...,
#         [138, 153, 169],
#         [138, 153, 169],
#         [137, 152, 168]],
#
#        [[144, 154, 172],
#         [144, 154, 172],
#         [144, 154, 172],
#         ...,
#         [138, 153, 169],
#         [137, 152, 168],
#         [137, 152, 168]],
#
#        [[144, 154, 172],
#         [144, 154, 172],
#         [144, 154, 172],
# ...

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(im1)
# Out:
# <PIL.Image.Image image mode=RGB size=544x1152 at 0x7F07DB9FB9E8>

# %%
cv2.imwrite('res_b1_view2.jpeg',im1)
# Out:
# True

# %%
print(x1,y1,w1,h1)
# Out:
# 206 285 172 284

# %%
print(x,y,w,h)
# Out:
# 229 353 151 260

# %%
volume = h*w*w1

# %%
import pandas as pd

# %%
image = 'bag1'

# %%
df = pd.DataFrame({'Image':[image],'Estimated Volume':[volume]})

# %%
print(df)
# Out:
#   Image  Estimated Volume
# 0  bag1           6752720

# %%
df.to_csv('volume.csv', index=False, header=True)
